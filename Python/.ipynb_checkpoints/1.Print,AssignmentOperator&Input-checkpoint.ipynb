# %% [markdown]
# ## Print

# %%
print("Hello")
# Out:
# Hello

# %%
num1=1
num2=2
add= num1+num2
sub=num1-num2

# %%
print(add)
print(sub)
# Out:
# 3
# -1

# %%
print(add)
# Out:
# 3

# %%
Print(add) # case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Print(add) # case sensitive
#
# NameError: name 'Print' is not defined

# %%
num1=int(input("Num1="))
num2=int(input("Num2="))
add= num1+num2
print("Add= ",add)
# Out:
# Num1= 30
# Num2= 67
# Add=  97
