# %%
pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-2.10.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.55.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (2.33.1)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-2.10.0-py3-none-any.whl (957 kB)
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/958.0 kB ? eta -:--:--
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    --------------------- ----------------- 524.3/958.0 kB 89.3 kB/s eta 0:00:05
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    -------------------------------- ------ 786.4/958.0 kB 67.4 kB/s eta 0:00:03
#    ---------------------------------------- 958.0/958.0 kB 67.5 kB/s  0:00:14
# Downloading google_auth-2.55.1-py3-none-any.whl (252 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
# Downloading cryptography-49.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    ----- ---------------------------------- 0.5/3.8 MB 52.3 kB/s eta 0:01:03
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    -------- ------------------------------- 0.8/3.8 MB 56.4 kB/s eta 0:00:54
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ----------- ---------------------------- 1.0/3.8 MB 71.2 kB/s eta 0:00:39
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ------------- -------------------------- 1.3/3.8 MB 71.2 kB/s eta 0:00:36
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ---------------- ----------------------- 1.6/3.8 MB 73.6 kB/s eta 0:00:31
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ------------------- -------------------- 1.8/3.8 MB 79.4 kB/s eta 0:00:25
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ---------------------- ----------------- 2.1/3.8 MB 83.1 kB/s eta 0:00:21
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    ------------------------ --------------- 2.4/3.8 MB 88.5 kB/s eta 0:00:17
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    --------------------------- ------------ 2.6/3.8 MB 92.4 kB/s eta 0:00:13
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    ------------------------------ --------- 2.9/3.8 MB 95.1 kB/s eta 0:00:10
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    --------------------------------- ------ 3.1/3.8 MB 101.3 kB/s eta 0:00:07
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    ----------------------------------- ---- 3.4/3.8 MB 102.5 kB/s eta 0:00:04
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    -------------------------------------- - 3.7/3.8 MB 104.2 kB/s eta 0:00:02
#    ---------------------------------------- 3.8/3.8 MB 102.5 kB/s  0:00:40
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Installing collected packages: websockets, tenacity, pyasn1, pyasn1-modules, cryptography, google-auth, google-genai
#
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ----- ---------------------------------- 1/7 [tenacity]
#    ----------- ---------------------------- 2/7 [pyasn1]
#    ----------- ---------------------------- 2/7 [pyasn1]
#    ----------- ---------------------------- 2/7 [pyasn1]
#    ----------- ---------------------------- 2/7 [pyasn1]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ----------------- ---------------------- 3/7 [pyasn1-modules]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-auth]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------- ----- 6/7 [google-genai]
#    ---------------------------------------- 7/7 [google-genai]
#
# Successfully installed cryptography-49.0.0 google-auth-2.55.1 google-genai-2.10.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 tenacity-9.1.4 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai

# %%
client = genai.Client(api_key="APIKey")

# %%
message =[]
system_msg = input("What is the type of bit you require?")

completion = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=system_msg
)
print(completion.text)
# Out:
# What is the type of bit you require? I want chef bot
# Ah, a new diner at my digital establishment! Welcome, welcome!
#
# **Chef Bot, at your service!** My apron is tied, my knives are sharp, and my spice rack is fully stocked.
#
# Tell me, what culinary delight are we dreaming up today?
#
# *   Do you need a **recipe** for a specific dish or ingredient?
# *   Are you looking for some **cooking tips** to perfect your technique?
# *   Want to explore **ingredient substitutions** or dietary alternatives?
# *   Just need some **inspiration** for your next meal?
# *   Or perhaps a **meal plan** for the week?
#
# **Let's get cooking!** What's on your mind?

# %%
messages =[]
system_msg = input("What is the type of bit you require?")
print(messages)

messages.append(
    f"You are a {system_msg} assistant."
)
print(messages)

print("your new assitant is ready!")
while input != "quit()":
    message = input()
    messages.append(message)
    print(messages)
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=messages
    )
    print(response.text)
    #response =  openai.chat.completions.create(
                #model="gpt-4o",
                #messages= messages
                #)
    #reply = response["choices"][0]["message"]["content"]
# Out:
# What is the type of bit you require? Chef bot
# []
# ['You are a Chef bot assistant.']
# your new assitant is ready!
#  pasta
# ['You are a Chef bot assistant.', 'pasta']
# Ah, **pasta**! A true culinary classic, so incredibly versatile, comforting, and endlessly delicious! My chef's heart sings just thinking about it.
#
# Tell me, what kind of pasta adventure are you looking for today? Are you craving:
#
# *   **A specific type of pasta?** (Spaghetti, penne, ravioli, tagliatelle, lasagna, orecchiette, or something else?)
# *   **A particular sauce?** (A classic marinara, creamy alfredo, vibrant pesto, hearty bolognese, zesty aglio e olio, a rich carbonara?)
# *   **A quick weeknight meal?**
# *   **Something more elaborate for a special occasion?**
# *   **Tips on making fresh pasta from scratch?**
# *   **Ideas for a vegetarian, vegan, or gluten-free pasta dish?**
# *   **A way to use up ingredients you already have?**
#
# Just give me a hint, and I'll whip up some fantastic pasta ideas for you! Let's get cooking! 🍝
#  cheese pasta
# ['You are a Chef bot assistant.', 'pasta', 'cheese pasta']
# Ah, pastacheese pasta! My friend, you've spoken the language of pure comfort and utter delight! There's nothing quite like a luscious, creamy, cheesy pasta to soothe the soul and tantalize the taste buds.
#
# As your Chef bot assistant, I'm absolutely thrilled to guide you through creating a masterpiece. Forget bland boxed versions; we're making **Cheesy Pasta Perfection: A Creamy, Dreamy Delight!**
#
# This recipe focuses on a rich, velvety cheese sauce that coats every single noodle in glorious cheesy goodness.
#
# ---
#
# ### Cheesy Pasta Perfection: A Creamy, Dreamy Delight!
#
# **Yields:** 4 generous servings
# **Prep time:** 15 minutes
# **Cook time:** 20-25 minutes
#
# #### What You'll Need (The Star Ingredients!):
#
# *   **For the Pasta:**
#     *   10-12 oz (280-340g) dry pasta (Elbow macaroni, cavatappi, shells, penne, or rotini work wonderfully!)
#     *   Salt for pasta water
#
# *   **For the Velvety Cheese Sauce:**
#     *   4 tablespoons unsalted butter
#     *   1/4 cup all-purpose flour
#     *   2 ½ cups whole milk (or 2% for a slightly lighter sauce), warmed slightly
#     *   2 cups (about 8 oz) freshly shredded sharp cheddar cheese (the sharper, the better!)
#     *   1 cup (about 4 oz) freshly shredded Gruyère, Fontina, or Monterey Jack cheese (for extra melty goodness and flavor complexity)
#     *   ½ teaspoon dry mustard powder (enhances the cheese flavor without tasting mustardy!)
#     *   ¼ teaspoon freshly grated nutmeg (the secret weapon for dairy-based sauces!)
#     *   Salt and freshly ground black pepper to taste
#     *   Optional: Pinch of cayenne pepper for a subtle kick
#     *   Optional: 1/4 cup finely minced shallot or yellow onion, and 1 clove garlic, minced (for extra depth of flavor)
#
# *   **For Garnish (Optional but Recommended!):**
#     *   Freshly chopped parsley or chives
#     *   Extra cracked black pepper
#
# #### Let's Get Cooking (Your Culinary Adventure Begins!):
#
# 1.  **Pasta First, Always!**
#     *   Bring a large pot of heavily salted water to a rolling boil. (It should taste like the ocean!)
#     *   Add your chosen pasta and cook according to package directions until **al dente**. This means it should be firm to the bite, not mushy.
#     *   Before draining, **reserve about 1 cup of the starchy pasta water**. This liquid gold will help you adjust the sauce consistency later.
#     *   Drain the pasta and set aside. Don't rinse it – the starch helps the sauce cling!
#
# 2.  **The Foundation: Building the Roux & Aromatics (If Using):**
#     *   In a large saucepan or Dutch oven, melt the butter over medium heat.
#     *   *If using aromatics:* Add the minced shallot/onion and cook until softened and translucent, about 3-4 minutes. Add the minced garlic and cook for another minute until fragrant (don't let it brown!).
#     *   Sprinkle in the flour (this is your **roux**!). Whisk constantly for 1-2 minutes until it forms a smooth paste and smells slightly toasty. This cooks out the raw flour taste.
#
# 3.  **Whisk in the Milk:**
#     *   Gradually pour in the warm milk, whisking continuously to prevent lumps. The mixture will thicken as it heats.
#     *   Continue to whisk and cook over medium heat until the sauce simmers gently and thickens enough to coat the back of a spoon, about 5-7 minutes.
#
# 4.  **The Glorious Cheese Meltdown!**
#     *   Remove the saucepan from the heat. This is crucial for a smooth sauce!
#     *   Add your shredded cheeses a handful at a time, stirring constantly until each addition is fully melted and incorporated before adding more.
#     *   Stir in the dry mustard, nutmeg, and cayenne (if using).
#     *   Taste the sauce and season generously with salt and freshly ground black pepper. Remember, cheese can be salty, so taste before adding too much!
#
# 5.  **Bring it All Together!**
#     *   Add the drained pasta to the creamy cheese sauce.
#     *   Stir gently to coat every strand and nook of the pasta in the glorious sauce.
#     *   If the sauce seems too thick, add a splash of the reserved pasta water, a tablespoon at a time, until it reaches your desired consistency.
#
# 6.  **Serve and Savor!**
#     *   Dish out your "Cheesy Pasta Perfection" immediately!
#     *   Garnish with fresh parsley or chives and an extra grind of black pepper, if desired.
#     *   Prepare for immediate comfort and pure joy!
#
# ---
#
# #### Chef's Tips for Perfection:
#
# *   **Freshly Grated Cheese is King:** Please, please, *please* grate your own cheese from a block! Pre-shredded cheeses often contain anti-caking agents that can make your sauce gritty.
# *   **Warm Milk Helps:** Warming the milk slightly before adding it to the roux helps create a smoother sauce and prevents lumps.
# *   **Don't Overcook the Pasta:** Al dente pasta provides the perfect texture contrast to the creamy sauce.
# *   **Gentle Heat for Cheese:** Adding cheese off the heat prevents it from seizing up and becoming grainy or oily.
# *   **Spice it Up!** A dash of hot sauce (like Tabasco) at the end can add a wonderful zing.
# *   **Add-ins:** Feel free to stir in cooked broccoli florets, peas, sautéed mushrooms, or even cooked shredded chicken for a more substantial meal.
#
# Enjoy every glorious, cheesy bite, my friend! This dish is a true testament to the simple pleasures of great ingredients and a little love in the kitchen. Let me know how it turns out!
#  quit()
# ['You are a Chef bot assistant.', 'pasta', 'cheese pasta', 'quit()']
# Understood! It sounds like we're closing the chapter on pastacheese pasta for now.
#
# What culinary adventure can I assist you with next? Are you looking for a new recipe, a cooking technique, or perhaps some ingredient substitutions? Let me know what's on your mind!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       8 print(messages)
#       9
#      10 print("your new assitant is ready!")
#      11 while input != "quit()":
# ---> 12     message = input()
#      13     messages.append(message)
#      14     print(messages)
#      15     response = client.models.generate_content(
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
