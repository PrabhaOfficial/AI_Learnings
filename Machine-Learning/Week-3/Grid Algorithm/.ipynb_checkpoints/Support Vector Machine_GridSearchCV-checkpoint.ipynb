# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int) # convert categorical into numerical dataset so that a model can be created

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns # get the column headers only
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='str')

# %%
#Get the independent/Input dataset alone
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent # Display the independant dataset
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
#Get the dependent/output dataset alone
dependent=dataset[["charges"]]

# %%
# Train the model using the training dataset
import  sklearn.model_selection as GSCV
from sklearn.svm import SVR
param_grid = {'kernel':['linear', 'rbf', 'poly', 'sigmoid'],'C':[10,1,.1,5000,4000],'gamma': ['auto', 'scale']}

# %%
grid =  GSCV.GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
re = grid.cv_results_
pd.DataFrame.from_dict(re)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.579922      0.070515         0.049985        0.011733       10
# 1        0.386613      0.067525         0.105811        0.056678       10
# 2        0.374965      0.043287         0.045542        0.014859       10
# 3        0.340948      0.115122         0.051977        0.028211       10
# 4        0.247488      0.057204         0.018226        0.008281        1
# 5        0.326642      0.005554         0.157122        0.048127        1
# 6        0.326805      0.064464         0.060853        0.030885        1
# 7        0.511298      0.085342         0.058233        0.028238        1
# 8        9.178746      1.756508         0.025156        0.020620     5000
# 9        0.453126      0.055370         0.169910        0.045223     5000
# 10       0.967784      0.370409         0.040507        0.025416     5000
# 11       0.697064      0.249541         0.120995        0.049639     5000
# 12       8.660242      1.845894         0.015694        0.004980     4000
# 13       0.552412      0.139063         0.223888        0.067555     4000
# 14       0.754685      0.209267         0.036751        0.018831     4000
# 15       0.387185      0.041659         0.063480        0.011870     4000
#
#    param_kernel                            params  split0_test_score  \
# 0        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 1           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 2          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 3       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 4        linear      {'C': 1, 'kernel': 'linear'}          -0.147592
# 5           rbf         {'C': 1, 'kernel': 'rbf'}          -0.115390
# 6          poly        {'C': 1, 'kernel': 'poly'}          -0.093867
# 7       sigmoid     {'C': 1, 'kernel': 'sigmoid'}          -0.115186
# 8        linear   {'C': 5000, 'kernel': 'linear'}           0.675403
# 9           rbf      {'C': 5000, 'kernel': 'rbf'}          -0.101592
# 10         poly     {'C': 5000, 'kernel': 'poly'}           0.146604
# 11      sigmoid  {'C': 5000, 'kernel': 'sigmoid'}         -41.235764
# 12       linear   {'C': 4000, 'kernel': 'linear'}           0.675782
# 13          rbf      {'C': 4000, 'kernel': 'rbf'}          -0.115990
# 14         poly     {'C': 4000, 'kernel': 'poly'}           0.093204
# 15      sigmoid  {'C': 4000, 'kernel': 'sigmoid'}         -26.856755
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.081505          -0.111907          -0.131602
# 3           -0.119312          -0.085214          -0.108210
# 4           -0.090685          -0.104805          -0.123874
# 5           -0.110235          -0.079858          -0.104068
# 6           -0.073490          -0.065017          -0.092734
# 7           -0.114434          -0.081691          -0.105744
# 8            0.622331           0.730635           0.632702
# 9           -0.050054          -0.071892          -0.090418
# 10           0.213077           0.162043           0.149387
# 11         -54.604842         -46.081742         -44.690976
# 12           0.622362           0.732388           0.633010
# 13          -0.063068          -0.085738          -0.103877
# 14           0.157414           0.106457           0.094242
# 15         -35.645101         -29.930262         -29.127891
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                5
# 1           -0.124428        -0.101276        0.016459                8
# 2           -0.179328        -0.125899        0.031794               13
# 3           -0.108716        -0.107639        0.012029               12
# 4           -0.202393        -0.133870        0.039226               14
# 5           -0.108358        -0.103582        0.012406                9
# 6           -0.112204        -0.087462        0.016613                6
# 7           -0.107748        -0.104961        0.012200               10
# 8            0.694594         0.671133        0.039919                2
# 9           -0.150877        -0.092967        0.033824                7
# 10           0.083869         0.150996        0.041241                3
# 11         -40.003347       -45.323334        5.140660               16
# 12           0.694627         0.671634        0.040389                1
# 13          -0.165535        -0.106842        0.034348               11
# 14           0.032055         0.096674        0.039947                4
# 15         -26.011785       -29.514359        3.383466               15

# %%
print("The r2 score value for best parameter {}:".format(grid.best_params_),grid.best_score_)

pred=grid.predict([[32,43.900,2,0,1]])
print(pred) #4449.46200
# Out:
# The r2 score value for best parameter {'C': 4000, 'kernel': 'linear'}: 0.671633545746395
# [37077.53040094]
# C:\Users\prabha_7589\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
